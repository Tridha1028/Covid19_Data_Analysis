# %% [markdown]
# # Imports

# %%
import sys
import os

import matplotlib as mpl

viz_path = r"E:/Python Pratice/Intern 2'/Data-Analytics-Projects-in-python-main/Data-Analytics-Projects-in-python-main/COVID19/visualizations"

# Add this path to the system path if it's not already there
if viz_path not in sys.path:
    sys.path.insert(0, viz_path) # Using insert(0,...) ensures it's checked first

# Now, Python can find your module
from covid_data_viz import CovidDataViz

print("Module 'CovidDataViz' imported successfully!")
# Out:
# Module 'CovidDataViz' imported successfully!

# %% [markdown]
# # Setup

# %%
mpl.rcParams['figure.figsize'] = (9, 5)

# %% [markdown]
# # Goal
# My goal is to visualize various aspect of the `COVID-19` pandemic. In this notebook we focus on a high level overview as well as the early days of the pandemic.

# %% [markdown]
# # Data sources
#
# In this notebook I use data from the following sources:
# - https://github.com/CSSEGISandData/COVID-19 - JHU CSSE COVID-19 Data.
# - https://datahub.io/JohnSnowLabs/country-and-continent-codes-list - country codes and continents.

# %% [markdown]
# # Data loading

# %% [markdown]
# See `src/visualizations/covid_data_viz.py` for code to load the data and reproduce the plots.

# %%
cdv = CovidDataViz()

# %% [markdown]
# # COVID19 - Globally
#
# The `SARS-CoV-2` disease was first discovered in `Wuhan, Hubei, China` in December 2019. The disease spread rapidly throught the world. In this notebook we see how rapidly and to what extent. Below we plot types of cases worlwide. At the time of writing `(2020-10-05)` the `confirmed` cases are nearing 35 milion.

# %%
cdv.plot_world_cases()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 cdv.plot_world_cases()
#
# File E:\Python Pratice/Intern 2'/Data-Analytics-Projects-in-python-main/Data-Analytics-Projects-in-python-main/COVID19/visualizations\covid_data_viz.py:160, in CovidDataViz.plot_world_cases(self)
#     153 """
#     154
#     155 Create world cases line plot.
#     156
#     157 """
#     159 df = self.get_world_ts()
# --> 160 self.plot_ts(df=df, title='World')
#
# File E:\Python Pratice/Intern 2'/Data-Analytics-Projects-in-python-main/Data-Analytics-Projects-in-python-main/COVID19/visualizations\covid_data_viz.py:207, in CovidDataViz.plot_ts(self, df, title)
#     204 plt.ylabel('Cases')
#     205 plt.legend(loc='best')
# --> 207 plt.savefig(f'../img/{title.lower()}_cases.png')
#     209 plt.tight_layout()
#
# File d:\conda_test\ssvenv\Lib\site-packages\matplotlib\pyplot.py:1251, in savefig(*args, **kwargs)
#    1248 fig = gcf()
#    1249 # savefig default implementation has no return, so mypy is unhappy
#    1250 # presumably this is here because subclasses can return?
# -> 1251 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1252 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1253 return res
#
# File d:\conda_test\ssvenv\Lib\site-packages\matplotlib\figure.py:3490, in Figure.savefig(self, fname, transparent, **kwargs)
#    3488     for ax in self.axes:
#    3489         _recursively_make_axes_transparent(stack, ax)
# -> 3490 self.canvas.print_figure(fname, **kwargs)
#
# File d:\conda_test\ssvenv\Lib\site-packages\matplotlib\backend_bases.py:2186, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2182 try:
#    2183     # _get_renderer may change the figure dpi (as vector formats
#    2184     # force the figure dpi to 72), so we need to set it again here.
#    2185     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2186         result = print_method(
#    2187             filename,
#    2188             facecolor=facecolor,
#    2189             edgecolor=edgecolor,
#    2190             orientation=orientation,
#    2191             bbox_inches_restore=_bbox_inches_restore,
#    2192             **kwargs)
#    2193 finally:
#    2194     if bbox_inches and restore_bbox:
#
# File d:\conda_test\ssvenv\Lib\site-packages\matplotlib\backend_bases.py:2042, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2038     optional_kws = {  # Passed by print_figure for other renderers.
#    2039         "dpi", "facecolor", "edgecolor", "orientation",
#    2040         "bbox_inches_restore"}
#    2041     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2042     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2043         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2044 else:  # Let third-parties do as they see fit.
#    2045     print_method = meth
#
# File d:\conda_test\ssvenv\Lib\site-packages\matplotlib\backends\backend_agg.py:481, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     434 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     435     """
#     436     Write the figure to a PNG file.
#     437
#    (...)    479         *metadata*, including the default 'Software' key.
#     480     """
# --> 481     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File d:\conda_test\ssvenv\Lib\site-packages\matplotlib\backends\backend_agg.py:430, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     425 """
#     426 Draw the canvas, then save it using `.image.imsave` (to which
#     427 *pil_kwargs* and *metadata* are forwarded).
#     428 """
#     429 FigureCanvasAgg.draw(self)
# --> 430 mpl.image.imsave(
#     431     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     432     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File d:\conda_test\ssvenv\Lib\site-packages\matplotlib\image.py:1657, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1655 pil_kwargs.setdefault("format", format)
#    1656 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1657 image.save(fname, **pil_kwargs)
#
# File d:\conda_test\ssvenv\Lib\site-packages\PIL\Image.py:2583, in Image.save(self, fp, format, **params)
#    2581         fp = builtins.open(filename, "r+b")
#    2582     else:
# -> 2583         fp = builtins.open(filename, "w+b")
#    2584 else:
#    2585     fp = cast(IO[bytes], fp)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../img/world_cases.png'

# %% [markdown]
# # COVID19 - By continent
#
# We drill down further into the data visualizing cases data at the continent level. Note that `Asia` is still exhibiting exponential growth and that the continent with least amount of `confirmed` cases is `Australia`.

# %%
for cont in cdv.all_continents:
    cdv.plot_continent_cases(cont)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 for cont in cdv.all_continents:
# ----> 2     cdv.plot_continent_cases(cont)
#
# File E:\Python Pratice/Intern 2'/Data-Analytics-Projects-in-python-main/Data-Analytics-Projects-in-python-main/COVID19/visualizations\covid_data_viz.py:180, in CovidDataViz.plot_continent_cases(self, continent)
#     173 """
#     174
#     175 Create continent cases line plot.
#     176
#     177 """
#     179 df = self.get_continent_ts(continent=continent)
# --> 180 self.plot_ts(df, continent)
#
# File E:\Python Pratice/Intern 2'/Data-Analytics-Projects-in-python-main/Data-Analytics-Projects-in-python-main/COVID19/visualizations\covid_data_viz.py:207, in CovidDataViz.plot_ts(self, df, title)
#     204 plt.ylabel('Cases')
#     205 plt.legend(loc='best')
# --> 207 plt.savefig(f'../img/{title.lower()}_cases.png')
#     209 plt.tight_layout()
#
# File d:\conda_test\ssvenv\Lib\site-packages\matplotlib\pyplot.py:1251, in savefig(*args, **kwargs)
#    1248 fig = gcf()
#    1249 # savefig default implementation has no return, so mypy is unhappy
#    1250 # presumably this is here because subclasses can return?
# -> 1251 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1252 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1253 return res
#
# File d:\conda_test\ssvenv\Lib\site-packages\matplotlib\figure.py:3490, in Figure.savefig(self, fname, transparent, **kwargs)
#    3488     for ax in self.axes:
#    3489         _recursively_make_axes_transparent(stack, ax)
# -> 3490 self.canvas.print_figure(fname, **kwargs)
#
# File d:\conda_test\ssvenv\Lib\site-packages\matplotlib\backend_bases.py:2186, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2182 try:
#    2183     # _get_renderer may change the figure dpi (as vector formats
#    2184     # force the figure dpi to 72), so we need to set it again here.
#    2185     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2186         result = print_method(
#    2187             filename,
#    2188             facecolor=facecolor,
#    2189             edgecolor=edgecolor,
#    2190             orientation=orientation,
#    2191             bbox_inches_restore=_bbox_inches_restore,
#    2192             **kwargs)
#    2193 finally:
#    2194     if bbox_inches and restore_bbox:
#
# File d:\conda_test\ssvenv\Lib\site-packages\matplotlib\backend_bases.py:2042, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2038     optional_kws = {  # Passed by print_figure for other renderers.
#    2039         "dpi", "facecolor", "edgecolor", "orientation",
#    2040         "bbox_inches_restore"}
#    2041     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2042     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2043         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2044 else:  # Let third-parties do as they see fit.
#    2045     print_method = meth
#
# File d:\conda_test\ssvenv\Lib\site-packages\matplotlib\backends\backend_agg.py:481, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     434 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     435     """
#     436     Write the figure to a PNG file.
#     437
#    (...)    479         *metadata*, including the default 'Software' key.
#     480     """
# --> 481     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File d:\conda_test\ssvenv\Lib\site-packages\matplotlib\backends\backend_agg.py:430, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     425 """
#     426 Draw the canvas, then save it using `.image.imsave` (to which
#     427 *pil_kwargs* and *metadata* are forwarded).
#     428 """
#     429 FigureCanvasAgg.draw(self)
# --> 430 mpl.image.imsave(
#     431     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     432     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File d:\conda_test\ssvenv\Lib\site-packages\matplotlib\image.py:1657, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1655 pil_kwargs.setdefault("format", format)
#    1656 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1657 image.save(fname, **pil_kwargs)
#
# File d:\conda_test\ssvenv\Lib\site-packages\PIL\Image.py:2583, in Image.save(self, fp, format, **params)
#    2581         fp = builtins.open(filename, "r+b")
#    2582     else:
# -> 2583         fp = builtins.open(filename, "w+b")
#    2584 else:
#    2585     fp = cast(IO[bytes], fp)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../img/africa_cases.png'

# %% [markdown]
# # COVID - By country
#
# Finally we can take a look at the data on a country level. First we show the countries with the most `cases`.

# %%
cdv.plot_highest_country_stats('Confirmed')

# %%
cdv.plot_highest_country_stats('Recovered')

# %%
cdv.plot_highest_country_stats('Dead')

# %%
cdv.plot_highest_country_stats('Active')

# %% [markdown]
# Then we show countries with `confirmed cases >= 1000` and the highest `mortality rate`.

# %%
cdv.plot_highest_country_stats('Mortality')

# %% [markdown]
# # COVID19 - Growth rates
#
# We proceed to visualize the early days of the pandemic. In most cases the growth was exponential as will be seen.
# We use the reindexed `confirmed_cases_t0.csv` file to plot growth curves starting at time `t0` ie  the date when a country achieved `Confirmed >= 100`. The charts are logarithmically scaled. Note that exponential growth on a logarithmic chart is a line. This follows from simple math. Furthermore observer that most of the countries in the plot are able to combat high exponential growth within `30` - `40` days since the `100`th case.

# %% [markdown]
# We plot exponential growth curves with different doubling rates against the countries with the most `confirmed cases`.

# %%
top_confirmed = sorted(cdv.get_most_cases('Confirmed')['Country'])

# %%
cdv.plot_growth(countries=top_confirmed[0:5], 
               periods=[2,4,8])

# %%
cdv.plot_growth(countries=top_confirmed[5:10], 
                periods=[2,4,8],
                save=True)

# %% [markdown]
# We plot the case growth curve against the countries with the highest `mortality rates`.

# %%
top_mortality = sorted(cdv.get_most_cases('Mortality')['Country'])

# %%
cdv.plot_growth(countries=top_mortality[0:5], 
               periods=[2,4,8])

# %%
cdv.plot_growth(countries=top_mortality[5:10], 
               periods=[2,4,8])

# %% [markdown]
# See the next notebook for more.
